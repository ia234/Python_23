# %% [markdown]
# <a href="https://colab.research.google.com/github/ia234/Python_23/blob/main/Wikipedia_Top_Articles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as urllib2
import time
from datetime import datetime
import json
from urllib.parse import urlencode, quote_plus

# %%
TOP_API_URL = 'https://wikimedia.org/api/rest_v1/metrics/pageviews/'\
              'top/{lang}.{project}/all-access/{year}/{month}/{day}'

def get_traffic(year, month, day):
    '''\
    Get the traffic report for the top 1000 articles for a given day.
    TODO: Get from local file, if available
    '''
    url = TOP_API_URL.format(lang='ar',
                             project='wikipedia',
                             year=year,
                             month=month,
                             day=day)
#     if DEBUG:
#         print 'Getting %s' % url
    resp = urllib2.urlopen(url)
    resp_bytes = resp.read()
#         rec.success('Fetched {len_bytes} bytes from {url}',
#                     len_bytes=len(resp_bytes), url=url)

    data = json.loads(resp_bytes)
    articles = data['items'][0]['articles']
    return articles

# %%
single_day = get_traffic('2023', '03','20')
print('These are the top', len(single_day), 'articles on the specified date above:')
# Out:
# These are the top 999 articles on the specified date above:

# %%
single_day_df = pd.DataFrame(single_day)
single_day_df
# Out:
#                      article  views  rank
# 0                   يوم_الأم  73739     1
# 1            الصفحة_الرئيسية  63985     2
# 2                    خاص:بحث  47311     3
# 3    قائمة_مباريات_الكلاسيكو  32586     4
# 4                  الكلاسيكو  31780     5
# ..                       ...    ...   ...
# 994               ياسر_عرفات    668   995
# 995              حلبة_(نبات)    668   995
# 996      كأس_الأمم_الإفريقية    668   995
# 997               بوابة:تصفح    668   995
# 998              قانون_مورفي    667   999
#
# [999 rows x 3 columns]

# %%
# Out:
# 996

# %%
MW_API_URL = 'https://{lang}.{project}.org/w/api.php?'
PREFIXES = ['Special', 'Template', 'Sp?cial', 'Project']

def get_wiki_info(lang, project):
    '''\
    Get the mainpage title and local namespace map.
    '''
    url = MW_API_URL.format(lang=lang, project=project)
    params = {'action': 'query',
              'meta': 'siteinfo',
              'format': 'json',
              'siprop': 'general|namespaces'}
    resp = urllib2.urlopen(url + urlencode(params))
    data = json.loads(resp.read())
    mainpage = data['query']['general']['mainpage'].replace(' ', '_')
    namespaces = [ns_info['*'].replace(' ', '_') for ns_id, ns_info in
                  data['query']['namespaces'].items() if ns_id is not 0]
    return {'mainpage': mainpage, 'namespaces': namespaces}
# Out:
# <>:17: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:17: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-4-d3fd4ef3e09a>:17: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   data['query']['namespaces'].items() if ns_id is not 0]

# %%
def is_article(title, wiki_info):
    '''\
    Is it an article, or some other sort of page? We'll want to filter out the
    search page (Special:Search in English, etc) and similar pages appearing
    inconveniently in the traffic report.
    Skip xhamster. There are a few clues this Wikipedia traffic is artificial.
    See https://en.wikipedia.org/w/index.php?title=XHamster&diff=701682670&oldid=700826198
    '''
    skip = ['-', '404.php', 'XHamster'] + [wiki_info['mainpage']]
    prefixes = PREFIXES + wiki_info['namespaces']
    if title in skip:
        return False
    if title == "Media":
        return False
    if title == "Wikipedia":
        return False
    if title == "United_States_Senate":
        return False
    for prefix in prefixes:
        if title.startswith(prefix + ':'):
            return False
    return True

# %%
wiki_info = get_wiki_info('en', 'wikipedia')
raw_traffic = get_traffic('2020', '02', '29')
articles = [a for a in raw_traffic if is_article(a['article'], wiki_info)]

# %%
len(articles[:25])
articles
# Out:
# [{'article': 'الصفحة_الرئيسية', 'views': 94409, 'rank': 1},
#  {'article': 'سنة_كبيسة', 'views': 57969, 'rank': 2},
#  {'article': 'خاص:بحث', 'views': 51984, 'rank': 3},
#  {'article': 'محمد_عمارة', 'views': 32059, 'rank': 4},
#  {'article': 'محمد_حسين_طنطاوي', 'views': 16058, 'rank': 5},
#  {'article': '29_فبراير', 'views': 13364, 'rank': 6},
#  {'article': 'ديانا_كرزون', 'views': 13146, 'rank': 7},
#  {'article': 'فيروس_كورونا', 'views': 10344, 'rank': 8},
#  {'article': 'ستيفن_هوكينج', 'views': 9706, 'rank': 9},
#  {'article': 'أذربيجان', 'views': 9676, 'rank': 10},
#  {'article': 'تفشي_فيروس_كورونا_المستجد_2019–20', 'views': 9569, 'rank': 11},
#  {'article': 'فيروس_كورونا_المستجد_2019', 'views': 9396, 'rank': 12},
#  {'article': 'حسني_مبارك', 'views': 8610, 'rank': 14},
#  {'article': 'فيروس_كورونا_المرتبط_بمتلازمة_الشرق_الأوسط_التنفسية',
#   'views': 7635,
#   'rank': 15},
#  {'article': 'طلال_بن_سعود_بن_عبد_العزيز_آل_سعود', 'views': 7373, 'rank': 16},
#  {'article': 'شيرين_وجدي', 'views': 7216, 'rank': 17},
#  {'article': 'قائمة_الدول_والتبعيات_حسب_عدد_السكان',
#   'views': 5118,
#   'rank': 18},
#  {'article': 'طالبان', 'views': 5004, 'rank': 19},
#  {'article': 'موسى_الكاظم', 'views': 4992, 'rank': 20},
#  {'article': 'دوري_أبطال_أفريقيا', 'views': 4853, 'rank': 21},
#  {'article': 'علاء_مبارك', 'views': 4501, 'rank': 22},
#  {'article': 'فبراير', 'views': 4371, 'rank': 23},
#  {'article': 'جمال_مبارك', 'views': 4349, 'rank': 24},
#  {'article': 'مجدي_يعقوب', 'views': 4340, 'rank': 25},
#  {'article': 'النادي_الأهلي_(مصر)', 'views': 4172, 'rank': 26},
#  {'article': 'شذى_سبت', 'views': 3921, 'rank': 27},
#  {'article': 'طاعون', 'views': 3819, 'rank': 28},
#  {'article': 'صلاة_الاستخارة', 'views': 3719, 'rank': 29},
#  {'article': 'عادل_إمام', 'views': 3654, 'rank': 30},
#  {'article': 'سوزان_مبارك', 'views': 3651, 'rank': 31},
#  {'article': 'مدحت_شلبي', 'views': 3565, 'rank': 32},
#  {'article': 'علامات_الساعة_في_الإسلام', 'views': 3480, 'rank': 34},
#  {'article': 'نادي_الزمالك', 'views': 3403, 'rank': 35},
#  {'article': 'مصر', 'views': 3315, 'rank': 36},
#  {'article': 'محمد', 'views': 3234, 'rank': 37},
#  {'article': 'السعودية', 'views': 3223, 'rank': 38},
#  {'article': 'عثمان_الأول', 'views': 3222, 'rank': 39},
#  {'article': 'الدولة_العثمانية', 'views': 3218, 'rank': 40},
#  {'article': 'الحرب_العالمية_الثانية', 'views': 3111, 'rank': 41},
#  {'article': 'التقويم_الميلادي', 'views': 3102, 'rank': 42},
#  {'article': 'لغة_إنجليزية', 'views': 3064, 'rank': 43},
#  {'article': 'الإنفلونزا_الإسبانية', 'views': 2973, 'rank': 44},
#  {'article': 'علي_بن_أبي_طالب', 'views': 2910, 'rank': 45},
#  {'article': 'آية_الكرسي', 'views': 2894, 'rank': 46},
#  {'article': 'يوتيوب', 'views': 2810, 'rank': 47},
#  {'article': 'سلمان_بن_عبد_العزيز_آل_سعود', 'views': 2775, 'rank': 48},
#  {'article': 'الحرب_العالمية_الأولى', 'views': 2753, 'rank': 49},
#  {'article': 'جماع', 'views': 2649, 'rank': 50},
#  {'article': 'الولايات_المتحدة', 'views': 2592, 'rank': 51},
#  {'article': 'عبد_الله_بوشهري', 'views': 2543, 'rank': 52},
#  {'article': 'أرطغرل', 'views': 2537, 'rank': 53},
#  {'article': 'محمد_رضا_بهلوي', 'views': 2486, 'rank': 54},
#  {'article': 'تويتر', 'views': 2480, 'rank': 55},
#  {'article': 'الكلاسيكو', 'views': 2440, 'rank': 56},
#  {'article': 'خاص:أحدث_التغييرات', 'views': 2399, 'rank': 57},
#  {'article': 'حلف_شمال_الأطلسي', 'views': 2384, 'rank': 58},
#  {'article': 'عمر_بن_الخطاب', 'views': 2383, 'rank': 59},
#  {'article': 'فيلم_إباحي', 'views': 2367, 'rank': 60},
#  {'article': 'تصنيف:ممثلات_إباحيات_أمريكيات', 'views': 2366, 'rank': 61},
#  {'article': 'الدولة_العباسية', 'views': 2365, 'rank': 62},
#  {'article': 'قابوس_بن_سعيد', 'views': 2333, 'rank': 63},
#  {'article': 'الشعر_العربي_في_عصر_صدر_الإسلام', 'views': 2329, 'rank': 64},
#  {'article': 'الموت_الأسود', 'views': 2328, 'rank': 65},
#  {'article': 'يوم_الأم', 'views': 2311, 'rank': 66},
#  {'article': 'تركيا', 'views': 2305, 'rank': 67},
#  {'article': 'شيماء_سبت', 'views': 2294, 'rank': 68},
#  {'article': 'قائمة_مفاتيح_الاتصال_الدولية', 'views': 2263, 'rank': 69},
#  {'article': 'بطولات_النادي_الأهلي_المصري_لكرة_القدم',
#   'views': 2246,
#   'rank': 70},
#  {'article': 'قائمة_محطات_مترو_القاهرة', 'views': 2237, 'rank': 71},
#  {'article': 'الصين', 'views': 2207, 'rank': 72},
#  {'article': 'أبو_بكر_الصديق', 'views': 2194, 'rank': 73},
#  {'article': 'سعود_بن_عبد_العزيز_آل_سعود', 'views': 2172, 'rank': 74},
#  {'article': 'هيدي_راسخ', 'views': 2169, 'rank': 75},
#  {'article': 'الدولة_الفاطمية', 'views': 2164, 'rank': 76},
#  {'article': 'عبد_الفتاح_السيسي', 'views': 2157, 'rank': 77},
#  {'article': 'بابلو_إسكوبار', 'views': 2156, 'rank': 78},
#  {'article': 'سوريا', 'views': 2150, 'rank': 79},
#  {'article': 'لوكسمبورغ', 'views': 2140, 'rank': 80},
#  {'article': 'أسرة_سعود_بن_عبد_العزيز_آل_سعود', 'views': 2082, 'rank': 81},
#  {'article': 'شيلاء_سبت', 'views': 2081, 'rank': 82},
#  {'article': 'الدوري_الإنجليزي_الممتاز', 'views': 2073, 'rank': 83},
#  {'article': 'الهند', 'views': 2063, 'rank': 84},
#  {'article': 'عبد_العزيز_آل_سعود', 'views': 2033, 'rank': 85},
#  {'article': 'دوري_أبطال_أوروبا', 'views': 2022, 'rank': 86},
#  {'article': 'صدام_حسين', 'views': 2011, 'rank': 87},
#  {'article': 'كريستيانو_رونالدو', 'views': 2009, 'rank': 88},
#  {'article': 'الأسطول_البحري_الجزائري', 'views': 2003, 'rank': 89},
#  {'article': 'محمد_بن_سلمان_آل_سعود', 'views': 1994, 'rank': 90},
#  {'article': 'فيسبوك', 'views': 1977, 'rank': 91},
#  {'article': 'قائمة_الدول_والتبعيات_حسب_المساحة', 'views': 1967, 'rank': 92},
#  {'article': 'علي_معلول', 'views': 1964, 'rank': 93},
#  {'article': 'خديجة_الجمال', 'views': 1947, 'rank': 94},
#  {'article': 'الجزائر', 'views': 1946, 'rank': 95},
#  {'article': 'الدولة_الأموية', 'views': 1944, 'rank': 96},
#  {'article': 'أنابيلا_هلال', 'views': 1941, 'rank': 97},
#  {'article': 'نجيب_محفوظ', 'views': 1930, 'rank': 98},
#  {'article': 'فيروس', 'views': 1930, 'rank': 98},
#  {'article': 'أسماء_الشهور', 'views': 1927, 'rank': 100},
#  {'article': 'تصنيف:ممثلات_إباحيات_حسب_الجنسية', 'views': 1925, 'rank': 101},
#  {'article': 'محمد_رمضان_(ممثل)', 'views': 1917, 'rank': 102},
#  {'article': 'لولوة_الملا', 'views': 1907, 'rank': 103},
#  {'article': 'قائمة_مباريات_الكلاسيكو', 'views': 1901, 'rank': 104},
#  {'article': 'عمرو_دياب', 'views': 1871, 'rank': 105},
#  {'article': 'الإمارات_العربية_المتحدة', 'views': 1852, 'rank': 106},
#  {'article': 'العراق', 'views': 1844, 'rank': 107},
#  {'article': '2020', 'views': 1830, 'rank': 108},
#  {'article': 'تقويم_ميلادي', 'views': 1814, 'rank': 109},
#  {'article': 'جين_وايلد_هوكينغ', 'views': 1814, 'rank': 109},
#  {'article': 'الشيعة', 'views': 1806, 'rank': 111},
#  {'article': 'جنس_شرجي', 'views': 1804, 'rank': 112},
#  {'article': 'المغرب', 'views': 1802, 'rank': 113},
#  {'article': 'الإسراء_والمعراج', 'views': 1800, 'rank': 114},
#  {'article': 'سحاقيات', 'views': 1798, 'rank': 115},
#  {'article': 'الصلاة_في_الإسلام', 'views': 1793, 'rank': 116},
#  {'article': 'العشرة_المبشرون_بالجنة', 'views': 1793, 'rank': 116},
#  {'article': 'ليونيل_ميسي', 'views': 1791, 'rank': 118},
#  {'article': 'أم_كلثوم_(مطربة)', 'views': 1786, 'rank': 119},
#  {'article': 'أصالة_نصري', 'views': 1781, 'rank': 120},
#  {'article': 'ألبرت_أينشتاين', 'views': 1779, 'rank': 121},
#  {'article': 'مص_القضيب', 'views': 1771, 'rank': 122},
#  {'article': 'ابن_سينا', 'views': 1770, 'rank': 123},
#  {'article': 'متلازمة_تنفسية_حادة_وخيمة', 'views': 1765, 'rank': 124},
#  {'article': 'نادي_برشلونة', 'views': 1750, 'rank': 125},
#  {'article': 'أبرار_سبت', 'views': 1747, 'rank': 126},
#  {'article': 'الوطن_العربي', 'views': 1744, 'rank': 127},
#  {'article': 'محمد_أنور_السادات', 'views': 1744, 'rank': 127},
#  {'article': 'اللغة_العربية', 'views': 1726, 'rank': 129},
#  {'article': 'وفيات_2020', 'views': 1722, 'rank': 130},
#  {'article': 'شمس_المعارف_الكبرى_(كتاب)', 'views': 1704, 'rank': 131},
#  {'article': 'فيصل_بن_عبد_العزيز_آل_سعود', 'views': 1700, 'rank': 132},
#  {'article': 'مرض_فيروس_كورونا_2019', 'views': 1692, 'rank': 133},
#  {'article': 'قيامة_أرطغرل_(مسلسل)', 'views': 1678, 'rank': 134},
#  {'article': 'ريال_مدريد', 'views': 1671, 'rank': 135},
#  {'article': 'المملكة_المتحدة', 'views': 1667, 'rank': 136},
#  {'article': 'كابريرا', 'views': 1660, 'rank': 137},
#  {'article': 'ماسونية', 'views': 1651, 'rank': 138},
#  {'article': 'نادي_أرسنال', 'views': 1650, 'rank': 139},
#  {'article': 'إيران', 'views': 1641, 'rank': 140},
#  {'article': 'عمر_سليمان', 'views': 1640, 'rank': 141},
#  {'article': 'ابن_خلدون', 'views': 1638, 'rank': 142},
#  {'article': 'إليزابيث_الثانية', 'views': 1633, 'rank': 143},
#  {'article': 'صلاح_الدين_الأيوبي', 'views': 1622, 'rank': 144},
#  {'article': 'توماس_إديسون', 'views': 1615, 'rank': 145},
#  {'article': 'الدول_الأعضاء_لحلف_الناتو', 'views': 1607, 'rank': 146},
#  {'article': 'شهر_حرام', 'views': 1598, 'rank': 147},
#  {'article': 'إمبراطورية_المغول', 'views': 1597, 'rank': 148},
#  {'article': 'متلازمة_القولون_المتهيج', 'views': 1595, 'rank': 149},
#  {'article': 'غسل_(إسلام)', 'views': 1594, 'rank': 150},
#  {'article': 'جنكيز_خان', 'views': 1594, 'rank': 150},
#  {'article': 'غزوة_بدر', 'views': 1582, 'rank': 152},
#  {'article': 'تنمر', 'views': 1580, 'rank': 153},
#  {'article': 'يوسف_القرضاوي', 'views': 1577, 'rank': 154},
#  {'article': 'ماميلودي_صن_داونز', 'views': 1576, 'rank': 155},
#  {'article': 'أفغانستان', 'views': 1574, 'rank': 156},
#  {'article': 'جمال_عبد_الناصر', 'views': 1572, 'rank': 157},
#  {'article': 'طاعون_عمواس', 'views': 1566, 'rank': 158},
#  {'article': 'الكويت', 'views': 1564, 'rank': 159},
#  {'article': 'علامات_الساعة_الصغرى', 'views': 1564, 'rank': 159},
#  {'article': 'أبو_الطيب_المتنبي', 'views': 1556, 'rank': 161},
#  {'article': 'القرآن', 'views': 1550, 'rank': 162},
#  {'article': 'عيون_الظلام_(رواية)', 'views': 1545, 'rank': 163},
#  {'article': 'خير_الدين_بربروس', 'views': 1544, 'rank': 164},
#  {'article': 'ملا_عمر', 'views': 1544, 'rank': 164},
#  {'article': 'كرة_القدم', 'views': 1542, 'rank': 166},
#  {'article': 'دلال_المغربي', 'views': 1530, 'rank': 167},
#  {'article': 'أدولف_هتلر', 'views': 1530, 'rank': 167},
#  {'article': 'يوبيل', 'views': 1529, 'rank': 169},
#  {'article': 'محمد_بن_إدريس_الشافعي', 'views': 1526, 'rank': 170},
#  {'article': 'إنفلونزا', 'views': 1511, 'rank': 171},
#  {'article': 'نظرية_كل_شيء_(فيلم)', 'views': 1509, 'rank': 172},
#  {'article': 'نادي_ليفربول', 'views': 1495, 'rank': 173},
#  {'article': 'ميا_خليفة', 'views': 1494, 'rank': 174},
#  {'article': 'فيروز_(مغنية)', 'views': 1490, 'rank': 175},
#  {'article': 'نادي_الاتحاد_(السعودية)', 'views': 1488, 'rank': 176},
#  {'article': 'القضية_الفلسطينية', 'views': 1486, 'rank': 177},
#  {'article': 'نادي_الرجاء_الرياضي', 'views': 1471, 'rank': 178},
#  {'article': 'كرة_السلة', 'views': 1471, 'rank': 178},
#  {'article': 'رجب_طيب_أردوغان', 'views': 1465, 'rank': 180},
#  {'article': 'قائمة_حلقات_المحقق_كونان', 'views': 1465, 'rank': 180},
#  {'article': 'نادي_الهلال_(السعودية)', 'views': 1455, 'rank': 182},
#  {'article': 'اضطراب_ثنائي_القطب', 'views': 1455, 'rank': 182},
#  {'article': 'عامر_منيب', 'views': 1454, 'rank': 184},
#  {'article': 'جنوب_أفريقيا', 'views': 1454, 'rank': 184},
#  {'article': 'محمد_صلاح', 'views': 1453, 'rank': 186},
#  {'article': 'سلطنة_عمان', 'views': 1453, 'rank': 186},
#  {'article': 'الإسلام_في_الهند', 'views': 1453, 'rank': 186},
#  {'article': 'تلوث_المياه', 'views': 1452, 'rank': 189},
#  {'article': 'محمود_بوشهري', 'views': 1451, 'rank': 190},
#  {'article': 'وضع_جنسي', 'views': 1446, 'rank': 191},
#  {'article': 'تقويم_هجري', 'views': 1440, 'rank': 192},
#  {'article': 'خالد_بن_الوليد', 'views': 1439, 'rank': 193},
#  {'article': 'بي_تي_أس', 'views': 1433, 'rank': 194},
#  {'article': 'غزوة_الخندق', 'views': 1431, 'rank': 195},
#  {'article': 'الحسين_بن_علي', 'views': 1420, 'rank': 196},
#  {'article': 'محمد_مرسي', 'views': 1406, 'rank': 197},
#  {'article': 'فلسطين', 'views': 1397, 'rank': 198},
#  {'article': 'تعريب_قيادة_الجيش_العربي', 'views': 1394, 'rank': 199},
#  {'article': 'ويكيبيديا:عن', 'views': 1393, 'rank': 200},
#  {'article': 'قصي_خولي', 'views': 1392, 'rank': 201},
#  {'article': 'طلال_بن_عبد_العزيز_آل_سعود', 'views': 1390, 'rank': 202},
#  {'article': 'عثمان_بن_عفان', 'views': 1388, 'rank': 203},
#  {'article': 'هيثم_بن_طارق', 'views': 1372, 'rank': 204},
#  {'article': 'الأردن', 'views': 1371, 'rank': 205},
#  {'article': 'قائمة_أعمال_عادل_إمام', 'views': 1368, 'rank': 206},
#  {'article': 'ديتمار_هوب', 'views': 1356, 'rank': 207},
#  {'article': 'قطر', 'views': 1355, 'rank': 208},
#  {'article': 'روسيا', 'views': 1351, 'rank': 209},
#  {'article': 'إسرائيل', 'views': 1344, 'rank': 210},
#  {'article': 'فاطمة_إسماعيل_(ممثلة)', 'views': 1344, 'rank': 210},
#  {'article': 'أفريقيا', 'views': 1336, 'rank': 212},
#  {'article': 'جدول_دوري', 'views': 1334, 'rank': 213},
#  {'article': 'مارس', 'views': 1327, 'rank': 214},
#  {'article': 'قائمة_محافظات_مصر', 'views': 1326, 'rank': 215},
#  {'article': 'الدولة_المرابطية', 'views': 1325, 'rank': 216},
#  {'article': 'فرنسا', 'views': 1318, 'rank': 217},
#  {'article': 'إيدز', 'views': 1311, 'rank': 218},
#  {'article': 'حرب_أكتوبر', 'views': 1309, 'rank': 219},
#  {'article': 'نرجسية', 'views': 1307, 'rank': 220},
#  {'article': 'السودان', 'views': 1304, 'rank': 221},
#  {'article': 'داء_كرون', 'views': 1298, 'rank': 222},
#  {'article': 'جنس_خارجي', 'views': 1292, 'rank': 223},
#  {'article': 'غزوة_أحد', 'views': 1292, 'rank': 223},
#  {'article': 'نادي_الوداد_الرياضي', 'views': 1290, 'rank': 225},
#  {'article': 'تلوث', 'views': 1280, 'rank': 226},
#  {'article': 'زمهرير_(مسلسل)', 'views': 1279, 'rank': 227},
#  {'article': '1_مارس', 'views': 1279, 'rank': 227},
#  {'article': 'حجم_قضيب_الإنسان', 'views': 1268, 'rank': 229},
#  {'article': 'المؤسس_عثمان_(مسلسل)', 'views': 1267, 'rank': 230},
#  {'article': 'استمناء', 'views': 1263, 'rank': 231},
#  {'article': 'اليابان', 'views': 1259, 'rank': 232},
#  {'article': 'زايد_بن_سلطان_آل_نهيان', 'views': 1259, 'rank': 232},
#  {'article': 'تطور_الحركة_الوطنية_الجزائرية_(1918-1954)',
#   'views': 1259,
#   'rank': 232},
#  {'article': 'أحلام_الشامسي', 'views': 1251, 'rank': 235},
#  {'article': 'هارون_الرشيد', 'views': 1251, 'rank': 235},
#  {'article': 'ماليزيا', 'views': 1248, 'rank': 237},
#  {'article': 'صوفية', 'views': 1245, 'rank': 238},
#  {'article': 'الإسلام', 'views': 1240, 'rank': 239},
#  {'article': 'الموحدون', 'views': 1237, 'rank': 240},
#  {'article': 'داليدا', 'views': 1233, 'rank': 241},
#  {'article': 'عجائب_الدنيا_السبع', 'views': 1230, 'rank': 242},
#  {'article': 'ملف:WhatsApp_logo-color-vertical.svg',
#   'views': 1230,
#   'rank': 242},
#  {'article': 'ألمانيا', 'views': 1230, 'rank': 242},
#  {'article': 'نزار_قباني', 'views': 1226, 'rank': 245},
#  {'article': 'شيرين_رضا', 'views': 1224, 'rank': 246},
#  {'article': 'ليلى_علوي', 'views': 1223, 'rank': 247},
#  {'article': 'عبد_الله_بن_عبد_العزيز_آل_سعود', 'views': 1221, 'rank': 248},
#  {'article': 'محمد_الفاتح', 'views': 1221, 'rank': 248},
#  {'article': 'الترجي_الرياضي_التونسي', 'views': 1214, 'rank': 250},
#  {'article': 'لا_كاسا_دي_بابيل', 'views': 1214, 'rank': 250},
#  {'article': 'الحجاج_بن_يوسف_الثقفي', 'views': 1211, 'rank': 252},
#  {'article': 'رشيد_بوجدرة', 'views': 1211, 'rank': 252},
#  {'article': 'قانون_أهداف_خارج_الديار', 'views': 1207, 'rank': 254},
#  {'article': 'قائمة_سور_القرآن_الكريم', 'views': 1207, 'rank': 254},
#  {'article': 'أحمد_شوقي', 'views': 1205, 'rank': 256},
#  {'article': 'المجموعة_الشمسية', 'views': 1205, 'rank': 256},
#  {'article': 'قضيب_الإنسان', 'views': 1203, 'rank': 258},
#  {'article': 'الإسكندر_الأكبر', 'views': 1202, 'rank': 259},
#  {'article': 'أبو_القاسم_الشابي', 'views': 1197, 'rank': 260},
#  {'article': 'قرامطة', 'views': 1197, 'rank': 260},
#  {'article': 'أبو_هريرة', 'views': 1194, 'rank': 262},
#  {'article': 'صلاة_الجنازة', 'views': 1190, 'rank': 263},
#  {'article': 'الحرب_الأهلية_السورية', 'views': 1189, 'rank': 264},
#  {'article': 'نانسي_عجرم', 'views': 1189, 'rank': 264},
#  {'article': 'الخطوط_السعودية', 'views': 1183, 'rank': 266},
#  {'article': 'اليونان', 'views': 1182, 'rank': 267},
#  {'article': 'الدولة_السلجوقية', 'views': 1181, 'rank': 268},
#  {'article': 'ووهان', 'views': 1177, 'rank': 269},
#  {'article': 'أفعال_خمسة', 'views': 1175, 'rank': 270},
#  {'article': 'عجائب_الدنيا', 'views': 1168, 'rank': 271},
#  {'article': 'أحمد_بن_حنبل', 'views': 1164, 'rank': 272},
#  {'article': 'أشرف_بنشرقي', 'views': 1164, 'rank': 272},
#  {'article': 'صفقة_القرن', 'views': 1161, 'rank': 274},
#  {'article': 'الخلفاء_الراشدون', 'views': 1161, 'rank': 274},
#  {'article': 'جوجل', 'views': 1159, 'rank': 276},
#  {'article': 'إيطاليا', 'views': 1158, 'rank': 277},
#  {'article': 'ابنة_السفير', 'views': 1158, 'rank': 277},
#  {'article': 'معركة_نافارين', 'views': 1156, 'rank': 279},
#  {'article': 'اختبار_القدرات', 'views': 1154, 'rank': 280},
#  {'article': 'هزة_الجماع', 'views': 1154, 'rank': 280},
#  {'article': 'قضيب_(عضو_ذكري)', 'views': 1153, 'rank': 282},
#  {'article': 'أسماء_الله_الحسنى', 'views': 1147, 'rank': 283},
#  {'article': 'فرج_(امرأة)', 'views': 1147, 'rank': 283},
#  {'article': 'ملك_حفني_ناصف', 'views': 1146, 'rank': 285},
#  {'article': 'إنترنت_مظلم', 'views': 1144, 'rank': 286},
#  {'article': 'حرب_الخليج_الثانية', 'views': 1142, 'rank': 287},
#  {'article': 'بيلي_إيليش', 'views': 1142, 'rank': 287},
#  {'article': 'إنفلونزا_الخنازير', 'views': 1141, 'rank': 289},
#  {'article': 'كم_جونغ_أون', 'views': 1139, 'rank': 290},
#  {'article': 'صباح_الأحمد_الجابر_الصباح', 'views': 1139, 'rank': 290},
#  {'article': 'محمود_درويش', 'views': 1137, 'rank': 292},
#  {'article': 'خالد_الفيصل_بن_عبد_العزيز_آل_سعود', 'views': 1133, 'rank': 293},
#  {'article': 'قائمة_أمثال_مصرية', 'views': 1132, 'rank': 294},
#  {'article': 'إن_وأخواتها', 'views': 1131, 'rank': 295},
#  {'article': 'مهبل', 'views': 1130, 'rank': 296},
#  {'article': 'لينين_الرملي', 'views': 1128, 'rank': 297},
#  {'article': 'نابليون_بونابرت', 'views': 1127, 'rank': 298},
#  {'article': 'تشبيه', 'views': 1127, 'rank': 298},
#  {'article': 'تونس', 'views': 1127, 'rank': 298},
#  {'article': 'سليمان_القانوني', 'views': 1127, 'rank': 298},
#  {'article': 'إسحاق_نيوتن', 'views': 1125, 'rank': 302},
#  {'article': 'عبد_الحميد_الثاني', 'views': 1125, 'rank': 302},
#  {'article': 'مايك_تايسون', 'views': 1125, 'rank': 302},
#  {'article': 'معاوية_بن_أبي_سفيان', 'views': 1124, 'rank': 305},
#  {'article': 'برج_فلكي', 'views': 1122, 'rank': 306},
#  {'article': 'جراند_ثفت_أوتو_5', 'views': 1122, 'rank': 306},
#  {'article': 'عائشة_بنت_أبي_بكر', 'views': 1117, 'rank': 308},
#  {'article': 'نوال_السعداوي', 'views': 1116, 'rank': 309},
#  {'article': 'قائمة_مباريات_ديربي_القاهرة', 'views': 1113, 'rank': 310},
#  {'article': 'عبد_القادر_الجزائري', 'views': 1112, 'rank': 311},
#  {'article': 'لودفيج_فان_بيتهوفن', 'views': 1109, 'rank': 312},
#  {'article': 'تاريخ_كأس_العالم_لكرة_القدم', 'views': 1106, 'rank': 313},
#  {'article': 'دونالد_ترامب', 'views': 1103, 'rank': 314},
#  {'article': 'الاتحاد_الأوروبي', 'views': 1103, 'rank': 314},
#  {'article': 'كبير_الياوران_(مصر)', 'views': 1102, 'rank': 316},
#  {'article': 'عمر_بن_عبد_العزيز', 'views': 1101, 'rank': 317},
#  {'article': 'تعداد_السكان_في_العالم', 'views': 1100, 'rank': 318},
#  {'article': 'عرب', 'views': 1098, 'rank': 319},
#  {'article': 'نادي_هوفنهايم', 'views': 1095, 'rank': 320},
#  {'article': 'إنستغرام', 'views': 1094, 'rank': 321},
#  {'article': 'مغول', 'views': 1091, 'rank': 322},
#  {'article': 'قائمة_الدول', 'views': 1090, 'rank': 323},
#  {'article': 'مجلس_التعاون_لدول_الخليج_العربية', 'views': 1089, 'rank': 324},
#  {'article': 'مروان_قنوع', 'views': 1089, 'rank': 324},
#  {'article': 'نيكولا_تسلا', 'views': 1087, 'rank': 326},
#  {'article': 'صوت_صفير_البلبل', 'views': 1085, 'rank': 327},
#  {'article': 'ثورة_التحرير_الجزائرية', 'views': 1083, 'rank': 328},
#  {'article': 'لوسي_هوكينغ', 'views': 1079, 'rank': 329},
#  {'article': 'دانييلا_رحمة', 'views': 1076, 'rank': 330},
#  {'article': 'كأس_العرب_للمنتخبات_تحت_20_سنة_2020',
#   'views': 1075,
#   'rank': 331},
#  {'article': 'سحاق', 'views': 1075, 'rank': 331},
#  {'article': 'إنترنت', 'views': 1074, 'rank': 333},
#  {'article': 'الاتحاد_السوفيتي', 'views': 1072, 'rank': 334},
#  {'article': 'عبد_الحليم_حافظ', 'views': 1072, 'rank': 334},
#  {'article': 'مستخدم:Mustafa/وصلاتي', 'views': 1072, 'rank': 334},
#  {'article': 'ويكيبيديا:مصادر_موثوق_بها', 'views': 1068, 'rank': 337},
#  {'article': 'فاطمة_الزهراء', 'views': 1066, 'rank': 338},
#  {'article': 'الاحتباس_الحراري', 'views': 1062, 'rank': 339},
#  {'article': 'فهد_بن_عبد_العزيز_آل_سعود', 'views': 1060, 'rank': 340},
#  {'article': 'كوليرا', 'views': 1059, 'rank': 341},
#  {'article': 'مصر_القديمة', 'views': 1058, 'rank': 342},
#  {'article': 'هندوسية', 'views': 1058, 'rank': 342},
#  {'article': 'محمد_بن_موسى_الخوارزمي', 'views': 1053, 'rank': 344},
#  {'article': 'صدقي_صبحي', 'views': 1052, 'rank': 345},
#  {'article': 'اليوم_العالمي_للمرأة', 'views': 1051, 'rank': 346},
#  {'article': 'بشار_الأسد', 'views': 1047, 'rank': 347},
#  {'article': 'معرض_أعلام_الدول', 'views': 1047, 'rank': 347},
#  {'article': 'عدوى_(فيلم)', 'views': 1041, 'rank': 349},
#  {'article': 'اكتئاب_(حالة_نفسية)', 'views': 1039, 'rank': 350},
#  {'article': 'كان_وأخواتها', 'views': 1038, 'rank': 351},
#  {'article': 'غرض_شعري', 'views': 1038, 'rank': 351},
#  {'article': 'المقاومة_الشعبية_الجزائرية_ضد_فرنسا',
#   'views': 1038,
#   'rank': 351},
#  {'article': 'فتح_مكة', 'views': 1037, 'rank': 354},
#  {'article': 'متلازمة_ستوكهولم', 'views': 1033, 'rank': 355},
#  {'article': 'محمد_بن_إسماعيل_البخاري', 'views': 1031, 'rank': 356},
#  {'article': 'نوال_الزغبي', 'views': 1029, 'rank': 357},
#  {'article': 'لص_بغداد_(فيلم_2020)', 'views': 1028, 'rank': 358},
#  {'article': 'طه_حسين', 'views': 1026, 'rank': 359},
#  {'article': 'شلل_النوم', 'views': 1026, 'rank': 359},
#  {'article': 'الدفاع_المدني_السعودي', 'views': 1025, 'rank': 361},
#  {'article': 'محمد_بن_راشد_آل_مكتوم', 'views': 1023, 'rank': 362},
#  {'article': 'منغوليا', 'views': 1022, 'rank': 363},
#  {'article': 'تيك_توك', 'views': 1022, 'rank': 363},
#  {'article': 'خديجة_بنت_خويلد', 'views': 1020, 'rank': 365},
#  {'article': 'الضوء_بين_المحيطات', 'views': 1019, 'rank': 366},
#  {'article': 'تصبيع', 'views': 1017, 'rank': 367},
#  {'article': 'اختبارات_القياس', 'views': 1014, 'rank': 368},
#  {'article': 'أهل_السنة_والجماعة', 'views': 1012, 'rank': 369},
#  {'article': 'جاكلين_كينيدي', 'views': 1007, 'rank': 370},
#  {'article': 'ابن_تيمية', 'views': 1005, 'rank': 371},
#  {'article': 'عتيبة_(قبيلة)', 'views': 1005, 'rank': 371},
#  {'article': 'المسجد_الأقصى', 'views': 1004, 'rank': 373},
#  {'article': 'الفلوس_(فيلم_2020)', 'views': 1004, 'rank': 373},
#  {'article': 'ويكيبيديا:إخلاء_مسؤولية_عام', 'views': 1003, 'rank': 375},
#  {'article': 'غشاء_البكارة', 'views': 1002, 'rank': 376},
#  {'article': 'كندا', 'views': 1002, 'rank': 376},
#  {'article': 'كوريا_الشمالية', 'views': 997, 'rank': 378},
#  {'article': 'فرح_ديبا', 'views': 997, 'rank': 378},
#  {'article': 'تصنيف:عواصم_آسيا', 'views': 996, 'rank': 380},
#  {'article': 'إلياس_الفخفاخ', 'views': 995, 'rank': 381},
#  {'article': 'موحدون_دروز', 'views': 993, 'rank': 382},
#  {'article': 'معركة_عين_جالوت', 'views': 992, 'rank': 383},
#  {'article': 'مرشد_سياحي', 'views': 992, 'rank': 383},
#  {'article': 'سورة_البقرة', 'views': 991, 'rank': 385},
#  {'article': 'عدي_بن_ربيعة', 'views': 990, 'rank': 386},
#  {'article': 'إثيوبيا', 'views': 989, 'rank': 387},
#  {'article': 'الأندلس', 'views': 985, 'rank': 388},
#  {'article': 'جماع_ثديي', 'views': 984, 'rank': 389},
#  {'article': 'نادي_النصر_(السعودية)', 'views': 984, 'rank': 389},
#  {'article': 'الأرض', 'views': 982, 'rank': 391},
#  {'article': 'أسامة_بن_لادن', 'views': 980, 'rank': 392},
#  {'article': 'تشي_جيفارا', 'views': 978, 'rank': 393},
#  {'article': 'باكستان', 'views': 978, 'rank': 393},
#  {'article': 'الحفرة_(مسلسل)', 'views': 976, 'rank': 395},
#  {'article': 'محمود_عباس', 'views': 974, 'rank': 396},
#  {'article': 'نهر_النيل', 'views': 973, 'rank': 397},
#  {'article': 'إسماعيلا_سار', 'views': 972, 'rank': 398},
#  {'article': 'قائمة_رؤساء_الولايات_المتحدة', 'views': 971, 'rank': 399},
#  {'article': 'المسيح_الدجال', 'views': 969, 'rank': 400},
#  {'article': 'كارمن_سليمان', 'views': 969, 'rank': 400},
#  {'article': 'أبو_بكر_الرازي', 'views': 969, 'rank': 400},
#  {'article': 'دورة_شهرية', 'views': 969, 'rank': 400},
#  {'article': 'اليمن', 'views': 968, 'rank': 404},
#  {'article': 'امرؤ_القيس', 'views': 968, 'rank': 404},
#  {'article': 'السخرية_في_أدب_الجاحظ', 'views': 963, 'rank': 406},
#  {'article': 'ضغط_الدم', 'views': 963, 'rank': 406},
#  {'article': 'ببجي', 'views': 961, 'rank': 408},
#  {'article': 'جزء_عم', 'views': 961, 'rank': 408},
#  {'article': 'الغزو_العراقي_للكويت', 'views': 959, 'rank': 410},
#  {'article': 'الزير_سالم_(مسلسل)', 'views': 959, 'rank': 410},
#  {'article': 'الرياض', 'views': 959, 'rank': 410},
#  {'article': 'الاتحاد_الدولي_لكرة_القدم', 'views': 958, 'rank': 413},
#  {'article': 'سكس', 'views': 957, 'rank': 414},
#  {'article': 'مصطفى_كمال_أتاتورك', 'views': 955, 'rank': 415},
#  {'article': 'مالك_بن_أنس', 'views': 951, 'rank': 416},
#  {'article': 'الدولة_المملوكية', 'views': 951, 'rank': 416},
#  {'article': 'جنس_فموي', 'views': 950, 'rank': 418},
#  {'article': 'قائمة_الأفلام_المصرية_سنة_2019', 'views': 950, 'rank': 418},
#  {'article': 'الفتح_الإسلامي_للمغرب', 'views': 950, 'rank': 418},
#  {'article': 'واي_باك_مشين', 'views': 948, 'rank': 421},
#  {'article': 'الدوري_الإسباني_لكرة_القدم', 'views': 947, 'rank': 422},
#  {'article': 'مانشستر_سيتي', 'views': 946, 'rank': 423},
#  {'article': 'سلوك_الإنسان_الجنسي', 'views': 946, 'rank': 423},
#  {'article': 'زلزال_أكادير_1960', 'views': 946, 'rank': 423},
#  {'article': 'علمانية', 'views': 945, 'rank': 426},
#  {'article': 'ختان_الإناث', 'views': 945, 'rank': 426},
#  {'article': 'سرطان', 'views': 945, 'rank': 426},
#  {'article': 'محمد_علي_باشا', 'views': 945, 'rank': 426},
#  {'article': 'استعارة', 'views': 945, 'rank': 426},
#  {'article': 'بيانو', 'views': 944, 'rank': 431},
#  {'article': 'لجين_الهذلول', 'views': 943, 'rank': 432},
#  {'article': 'لبنان', 'views': 942, 'rank': 433},
#  {'article': 'أحمد_السقا', 'views': 941, 'rank': 434},
#  {'article': 'تصنيف:أفلام_عن_الجنس', 'views': 940, 'rank': 435},
#  {'article': 'جورج_وسوف', 'views': 939, 'rank': 436},
#  {'article': 'بظر', 'views': 938, 'rank': 437},
#  {'article': 'أحمد_زويل', 'views': 937, 'rank': 438},
#  {'article': 'البحرين', 'views': 935, 'rank': 439},
#  {'article': 'روبوت', 'views': 934, 'rank': 440},
#  {'article': 'مؤتمر_الصومام', 'views': 933, 'rank': 441},
#  {'article': 'كريستوفر_كولومبوس', 'views': 932, 'rank': 442},
#  {'article': 'أستراليا', 'views': 932, 'rank': 442},
#  {'article': 'كوريا_الجنوبية', 'views': 932, 'rank': 442},
#  {'article': 'محمد_قنوع', 'views': 931, 'rank': 445},
#  {'article': 'روبن_ويليامز', 'views': 930, 'rank': 446},
#  {'article': 'هبة_الله_أخوند_زاده', 'views': 928, 'rank': 447},
#  {'article': 'دينا_الشربيني', 'views': 928, 'rank': 447},
#  {'article': 'انفجار_سكاني', 'views': 927, 'rank': 449},
#  {'article': 'هيفاء_وهبي', 'views': 927, 'rank': 449},
#  {'article': 'عيسى_بن_مريم', 'views': 926, 'rank': 451},
#  {'article': 'يسرا', 'views': 925, 'rank': 452},
#  {'article': 'مثلية_جنسية', 'views': 925, 'rank': 452},
#  {'article': 'أرقام_الهاتف_في_السعودية', 'views': 925, 'rank': 452},
#  {'article': 'ملف:Uruguay1930.JPG', 'views': 924, 'rank': 455},
#  {'article': 'التهاب_الزائدة_الدودية', 'views': 922, 'rank': 456},
#  {'article': 'تنمية_بشرية', 'views': 920, 'rank': 457},
#  {'article': 'وسيم_يوسف', 'views': 920, 'rank': 457},
#  {'article': 'شيوعية', 'views': 920, 'rank': 457},
#  {'article': 'توت_عنخ_آمون', 'views': 918, 'rank': 460},
#  {'article': '69_(وضعية_جنسية)', 'views': 916, 'rank': 461},
#  {'article': 'حسن_حسني', 'views': 914, 'rank': 462},
#  {'article': 'مازن_دياب', 'views': 913, 'rank': 463},
#  {'article': 'جعفر_الصادق', 'views': 912, 'rank': 464},
#  {'article': 'علم_النفس', 'views': 911, 'rank': 465},
#  {'article': 'عنترة_بن_شداد', 'views': 910, 'rank': 466},
#  {'article': 'المسجد_النبوي', 'views': 909, 'rank': 467},
#  {'article': 'الثورة_الفرنسية', 'views': 909, 'rank': 467},
#  {'article': 'القاهرة', 'views': 907, 'rank': 469},
#  {'article': 'الأخ_الكبير_(مسلسل)', 'views': 906, 'rank': 470},
#  {'article': 'ذكاء_اصطناعي', 'views': 905, 'rank': 471},
#  {'article': 'جامع_عقبة_بن_نافع', 'views': 905, 'rank': 471},
#  {'article': 'إنفلونزا_الطيور', 'views': 903, 'rank': 473},
#  {'article': 'لعق_(وضع_جنسي)', 'views': 903, 'rank': 473},
#  {'article': 'سجع', 'views': 902, 'rank': 475},
#  {'article': 'أمازيغ', 'views': 902, 'rank': 475},
#  {'article': 'قائمة_الأندية_الفائزة_بالدوري_الإنجليزي_الممتاز',
#   'views': 902,
#   'rank': 475},
#  {'article': 'الجاحظ', 'views': 901, 'rank': 478},
#  {'article': 'ابن_الهيثم', 'views': 901, 'rank': 478},
#  {'article': 'سور_الصين_العظيم', 'views': 898, 'rank': 480},
#  {'article': 'حرب_البسوس', 'views': 897, 'rank': 481},
#  {'article': 'كاثرين_جونسون', 'views': 897, 'rank': 481},
#  {'article': 'كسكس', 'views': 896, 'rank': 483},
#  {'article': 'آل_سعود', 'views': 896, 'rank': 483},
#  {'article': 'سد_النهضة', 'views': 894, 'rank': 485},
#  {'article': 'دوري_المحترفين_السعودي', 'views': 890, 'rank': 486},
#  {'article': 'تصحر', 'views': 888, 'rank': 487},
#  {'article': 'حرارة_الجسم_البشري', 'views': 887, 'rank': 488},
#  {'article': 'الإمبراطورية_البيزنطية', 'views': 887, 'rank': 488},
#  {'article': 'مانشستر_يونايتد', 'views': 886, 'rank': 490},
#  {'article': 'إبراهيم', 'views': 885, 'rank': 491},
#  {'article': 'نوح', 'views': 880, 'rank': 492},
#  {'article': 'أوروبا', 'views': 880, 'rank': 492},
#  {'article': 'حبيب_العادلي', 'views': 879, 'rank': 494},
#  {'article': 'سويسرا', 'views': 878, 'rank': 495},
#  {'article': 'أسرة_سلطان_بن_عبد_العزيز_آل_سعود', 'views': 874, 'rank': 496},
#  {'article': 'إسبانيا', 'views': 873, 'rank': 497},
#  {'article': 'برج_خليفة', 'views': 872, 'rank': 498},
#  {'article': 'الميراث_(مسلسل)', 'views': 872, 'rank': 498},
#  {'article': 'المدينة_المنورة', 'views': 871, 'rank': 500},
#  {'article': 'الشاب_خالد', 'views': 870, 'rank': 501},
#  {'article': 'قائمة_أسماء_الحيوانات_وإناثها_وصغارها',
#   'views': 870,
#   'rank': 501},
#  {'article': 'محمد_متولي_الشعراوي', 'views': 867, 'rank': 503},
#  {'article': 'طفيلي_(فيلم)', 'views': 865, 'rank': 504},
#  {'article': 'يأجوج_ومأجوج', 'views': 865, 'rank': 504},
#  {'article': 'عبد_الرحمن_بن_سعود_بن_عبد_العزيز_آل_سعود',
#   'views': 865,
#   'rank': 504},
#  {'article': 'مايكل_جاكسون', 'views': 864, 'rank': 507},
#  {'article': 'مكة', 'views': 863, 'rank': 508},
#  {'article': 'أبو_حنيفة_النعمان', 'views': 863, 'rank': 508},
#  {'article': 'رؤى_الصبان', 'views': 862, 'rank': 510},
#  {'article': 'فريمان_دايسون', 'views': 860, 'rank': 511},
#  {'article': 'التشهد', 'views': 860, 'rank': 511},
#  {'article': 'أسد', 'views': 859, 'rank': 513},
#  {'article': 'سر_(مسلسل)', 'views': 857, 'rank': 514},
#  {'article': 'قائمة_الصحابة', 'views': 855, 'rank': 515},
#  {'article': 'سيد_درويش', 'views': 855, 'rank': 515},
#  {'article': 'الحسين_بن_طلال', 'views': 855, 'rank': 515},
#  {'article': 'ويكيبيديا_العربية', 'views': 853, 'rank': 518},
#  {'article': 'محمد_حماقي', 'views': 851, 'rank': 519},
#  {'article': 'مرض_فيروس_إيبولا', 'views': 851, 'rank': 519},
#  {'article': 'ديانا_أميرة_ويلز', 'views': 850, 'rank': 521},
#  {'article': 'جون_كينيدي', 'views': 849, 'rank': 522},
#  {'article': 'المنظمة_الخاصة', 'views': 848, 'rank': 523},
#  {'article': 'المعلقات', 'views': 847, 'rank': 524},
#  {'article': 'قلب', 'views': 846, 'rank': 525},
#  {'article': 'الصوم_الكبير', 'views': 846, 'rank': 525},
#  {'article': 'منظمة_الصحة_العالمية', 'views': 845, 'rank': 527},
#  {'article': 'حمزة_بن_عبد_المطلب', 'views': 845, 'rank': 527},
#  {'article': 'تقويم_قبطي', 'views': 845, 'rank': 527},
#  {'article': 'فتنة_مقتل_عثمان', 'views': 845, 'rank': 527},
#  {'article': 'قائمة_أصوات_الحيوانات', 'views': 844, 'rank': 531},
#  {'article': 'أهرام_الجيزة', 'views': 843, 'rank': 532},
#  {'article': 'الإعجاز_العلمي_في_القرآن', 'views': 843, 'rank': 532},
#  {'article': 'قائمة_سلاطين_الدولة_العثمانية', 'views': 842, 'rank': 534},
#  {'article': 'الرمز_البريدي_(السعودية)', 'views': 841, 'rank': 535},
#  {'article': 'مهاتير_محمد', 'views': 840, 'rank': 536},
#  {'article': 'جناس', 'views': 839, 'rank': 537},
#  {'article': 'روح_الله_الخميني', 'views': 834, 'rank': 538},
#  {'article': 'القناة_الرياضية_السعودية', 'views': 833, 'rank': 539},
#  {'article': 'إندونيسيا', 'views': 833, 'rank': 539},
#  {'article': 'صحيح_البخاري', 'views': 833, 'rank': 539},
#  {'article': 'ليبيا', 'views': 832, 'rank': 542},
#  {'article': 'سل', 'views': 831, 'rank': 543},
#  {'article': 'تميم_بن_حمد_بن_خليفة_آل_ثاني', 'views': 831, 'rank': 543},
#  {'article': 'شيرين_عبد_الوهاب', 'views': 831, 'rank': 543},
#  {'article': 'محمد_عبده_(مغني)', 'views': 829, 'rank': 546},
#  {'article': 'محمد_علي', 'views': 827, 'rank': 547},
#  {'article': 'سنغافورة', 'views': 827, 'rank': 547},
#  {'article': 'القدس', 'views': 826, 'rank': 549},
#  {'article': 'الدوري_المصري_الممتاز', 'views': 825, 'rank': 550},
#  {'article': 'ويكيبيديا:الاستشهاد_بمصادر', 'views': 824, 'rank': 551},
#  {'article': 'حديث_نبوي', 'views': 824, 'rank': 551},
#  {'article': 'باب_الحارة', 'views': 823, 'rank': 553},
#  {'article': 'سرعة_القلب', 'views': 821, 'rank': 554},
#  {'article': 'صلح_الحديبية', 'views': 820, 'rank': 555},
#  {'article': 'حرب_بيولوجية', 'views': 820, 'rank': 555},
#  {'article': 'جوكر_(فيلم_2019)', 'views': 813, 'rank': 557},
#  {'article': 'جرادة_(حشرة)', 'views': 813, 'rank': 557},
#  {'article': 'فاروق_الأول', 'views': 812, 'rank': 559},
#  {'article': 'مجازر_8_ماي_1945', 'views': 812, 'rank': 559},
#  {'article': 'ذا_ماتريكس_(فيلم)', 'views': 812, 'rank': 559},
#  {'article': 'النادي_الأهلي_(السعودية)', 'views': 810, 'rank': 562},
#  {'article': 'محمد_إمام', 'views': 810, 'rank': 562},
#  {'article': 'موناليزا', 'views': 810, 'rank': 562},
#  {'article': 'الكعبة', 'views': 809, 'rank': 565},
#  {'article': 'رتبة_عسكرية', 'views': 809, 'rank': 565},
#  {'article': 'قائمة_العلماء_المسلمين', 'views': 808, 'rank': 567},
#  {'article': 'بيل_غيتس', 'views': 807, 'rank': 568},
#  {'article': 'انتصاب_القضيب', 'views': 807, 'rank': 568},
#  {'article': 'خط_عربي', 'views': 807, 'rank': 568},
#  {'article': 'ذاكر_نايك', 'views': 806, 'rank': 571},
#  {'article': 'رمز_الهاتف_الدولي', 'views': 805, 'rank': 572},
#  {'article': 'قائمة_العناصر_الكيميائية', 'views': 803, 'rank': 573},
#  {'article': 'شجون_الهاجري', 'views': 801, 'rank': 574},
#  {'article': 'محمد_المهدي', 'views': 801, 'rank': 574},
#  {'article': 'كثافة_سكانية', 'views': 801, 'rank': 574},
#  {'article': 'هالة_مصطفى', 'views': 800, 'rank': 577},
#  {'article': 'محيي_الدين_بن_عربي', 'views': 800, 'rank': 577},
#  {'article': 'خواكين_غوزمان_لويرا', 'views': 800, 'rank': 577},
#  {'article': 'زكريا_أحمد', 'views': 800, 'rank': 577},
#  {'article': 'جامعة_الدول_العربية', 'views': 798, 'rank': 581},
#  {'article': 'حرب', 'views': 797, 'rank': 582},
#  {'article': 'كرة_اليد', 'views': 795, 'rank': 583},
#  {'article': 'مصالي_الحاج', 'views': 795, 'rank': 583},
#  {'article': 'نوميديا', 'views': 794, 'rank': 585},
#  {'article': 'بايرن_ميونخ', 'views': 793, 'rank': 586},
#  {'article': 'عاصي_الحلاني', 'views': 793, 'rank': 586},
#  {'article': 'نيوم', 'views': 793, 'rank': 586},
#  {'article': 'مناطق_انتشار_فيروس_كورونا_ووهان_الجديد_بالدولة_والمنطقة_2019-2020',
#   'views': 792,
#   'rank': 589},
#  {'article': 'البحر_الأحمر', 'views': 791, 'rank': 590},
#  {'article': 'إيالة_الجزائر', 'views': 788, 'rank': 591},
#  {'article': 'تدلاك', 'views': 787, 'rank': 592},
#  {'article': 'عبلة_كامل', 'views': 787, 'rank': 592},
#  {'article': 'البتراء', 'views': 787, 'rank': 592},
#  {'article': 'تدخين', 'views': 787, 'rank': 592},
#  {'article': 'يوسف_بن_تاشفين', 'views': 786, 'rank': 596},
#  {'article': 'عائلة_روتشيلد', 'views': 786, 'rank': 596},
#  {'article': 'موسى', 'views': 786, 'rank': 596},
#  {'article': 'بكتيريا', 'views': 786, 'rank': 596},
#  {'article': 'الدول_الأعضاء_في_الاتحاد_الأوروبي', 'views': 785, 'rank': 600},
#  {'article': 'بروس_لي', 'views': 785, 'rank': 600},
#  {'article': 'دوندار_بن_سليمان_شاه', 'views': 785, 'rank': 600},
#  {'article': 'عائض_القرني', 'views': 785, 'rank': 600},
#  {'article': 'عروج_بربروس', 'views': 785, 'rank': 600},
#  {'article': 'قائمة_أسماء_قادة_الولايات_الستة_(الثورة_الجزائرية)',
#   'views': 784,
#   'rank': 605},
#  {'article': 'قائمة_أسماء_الأسد_في_اللغة_العربية', 'views': 784, 'rank': 605},
#  {'article': 'هنا_الزاهد', 'views': 784, 'rank': 605},
#  {'article': 'ويكيبيديا', 'views': 783, 'rank': 608},
#  {'article': 'جمال_حمزة', 'views': 783, 'rank': 608},
#  {'article': 'السكري', 'views': 781, 'rank': 610},
#  {'article': 'رياضيات', 'views': 781, 'rank': 610},
#  {'article': 'مثلث_برمودا', 'views': 780, 'rank': 612},
#  {'article': 'حب', 'views': 780, 'rank': 612},
#  {'article': 'معركة_اليرموك', 'views': 779, 'rank': 614},
#  {'article': 'عيالة', 'views': 779, 'rank': 614},
#  {'article': 'المالديف', 'views': 779, 'rank': 614},
#  {'article': 'أسرة_عبد_العزيز_بن_عبد_الرحمن_آل_سعود',
#   'views': 778,
#   'rank': 617},
#  {'article': 'قائمة_الأعلام_حسب_عدد_الألوان', 'views': 778, 'rank': 617},
#  {'article': 'نتفليكس', 'views': 778, 'rank': 617},
#  {'article': 'سعاد_حسني', 'views': 778, 'rank': 617},
#  {'article': 'قائمة_الأوبئة', 'views': 772, 'rank': 621},
#  {'article': 'حسن_البنا', 'views': 771, 'rank': 622},
#  {'article': 'الأئمة_الاثنا_عشر', 'views': 769, 'rank': 623},
#  {'article': 'بقعة_جي', 'views': 769, 'rank': 623},
#  {'article': 'فينيقيون', 'views': 766, 'rank': 625},
#  {'article': 'تجارة_الأعضاء', 'views': 766, 'rank': 625},
#  {'article': 'قائمة_ملوك_السعودية', 'views': 763, 'rank': 627},
#  {'article': 'قم', 'views': 763, 'rank': 627},
#  {'article': 'قائمة_الأحداث_التاريخية', 'views': 763, 'rank': 627},
#  {'article': 'كاظم_الساهر', 'views': 762, 'rank': 630},
#  {'article': 'قاعدة_بيانات_الأفلام_على_الإنترنت', 'views': 762, 'rank': 630},
#  {'article': 'نادي_واتفورد', 'views': 760, 'rank': 632},
#  {'article': 'آدم', 'views': 760, 'rank': 632},
#  {'article': 'ديانا_حداد', 'views': 760, 'rank': 632},
#  {'article': 'ستيف_جوبز', 'views': 757, 'rank': 635},
#  {'article': 'نور_الشريف', 'views': 755, 'rank': 636},
#  {'article': 'إنسان', 'views': 755, 'rank': 636},
#  {'article': 'الداي_حسين', 'views': 755, 'rank': 636},
#  {'article': 'اغتصاب', 'views': 755, 'rank': 636},
#  {'article': 'أحمد_عرابي', 'views': 754, 'rank': 640},
#  {'article': 'عمر_الشريف', 'views': 754, 'rank': 640},
#  {'article': 'أحمد_زكي', 'views': 754, 'rank': 640},
#  {'article': 'ثقب_أسود', 'views': 753, 'rank': 643},
#  {'article': 'أفعال_الشروع', 'views': 753, 'rank': 643},
#  {'article': 'قائمة_الدول_العربية_حسب_عدد_السكان', 'views': 753, 'rank': 643},
#  {'article': 'خالد_عبد_الرحمن', 'views': 752, 'rank': 646},
#  {'article': 'الإخوان_المسلمون', 'views': 750, 'rank': 647},
#  {'article': 'طيور_الجنة_(قناة)', 'views': 750, 'rank': 647},
#  {'article': 'علي_خامنئي', 'views': 750, 'rank': 647},
#  {'article': 'مهاتما_غاندي', 'views': 750, 'rank': 647},
#  {'article': 'اليوم_العالمي_للدفاع_المدني', 'views': 749, 'rank': 651},
#  {'article': 'خوان_كارلوس_غاريدو', 'views': 749, 'rank': 651},
#  {'article': 'كريم_عبد_العزيز', 'views': 749, 'rank': 651},
#  {'article': 'حاسوب', 'views': 748, 'rank': 654},
#  {'article': 'ممثل_إباحي', 'views': 748, 'rank': 654},
#  {'article': 'بهائية', 'views': 748, 'rank': 654},
#  {'article': 'تاج_محل', 'views': 747, 'rank': 657},
#  {'article': 'ماء', 'views': 747, 'rank': 657},
#  {'article': 'القسطنطينية', 'views': 747, 'rank': 657},
#  {'article': 'خالد_بن_عبد_العزيز_آل_سعود', 'views': 746, 'rank': 660},
#  {'article': 'سيد_قطب', 'views': 745, 'rank': 661},
#  {'article': 'ذات_الرئة', 'views': 745, 'rank': 661},
#  {'article': 'لانا_روادس', 'views': 745, 'rank': 661},
#  {'article': 'الحسن_بن_علي', 'views': 745, 'rank': 661},
#  {'article': 'الإمبراطورية_الرومانية', 'views': 744, 'rank': 665},
#  {'article': 'سادية', 'views': 743, 'rank': 666},
#  {'article': 'ون_بيس', 'views': 741, 'rank': 667},
#  {'article': 'عمر_المختار', 'views': 740, 'rank': 668},
#  {'article': 'آر_إم_إس_تيتانيك', 'views': 740, 'rank': 668},
#  {'article': 'أركان_الإسلام', 'views': 740, 'rank': 668},
#  {'article': 'جبران_خليل_جبران', 'views': 739, 'rank': 671},
#  {'article': 'سافانا', 'views': 739, 'rank': 671},
#  {'article': 'أبو_عبيدة_بن_الجراح', 'views': 739, 'rank': 671},
#  {'article': 'تنظيم_الدولة_الإسلامية_(داعش)', 'views': 738, 'rank': 674},
#  {'article': 'زراعة', 'views': 738, 'rank': 674},
#  {'article': 'موريتانيا', 'views': 737, 'rank': 676},
#  {'article': 'مرض_باركنسون', 'views': 736, 'rank': 677},
#  {'article': 'أشعة_سينية', 'views': 736, 'rank': 677},
#  {'article': 'محمد_بن_زايد_آل_نهيان', 'views': 736, 'rank': 677},
#  {'article': 'رومان_بولانسكي', 'views': 736, 'rank': 677},
#  {'article': 'كأس_السوبر_المصري', 'views': 735, 'rank': 681},
#  {'article': 'نادين_نسيب_نجيم', 'views': 734, 'rank': 682},
#  {'article': 'ستاد_القاهرة_الدولي', 'views': 732, 'rank': 683},
#  {'article': 'هولاكو_خان', 'views': 732, 'rank': 683},
#  {'article': 'قائمة_الدول_حسب_الناتج_المحلي_الإجمالي',
#   'views': 730,
#   'rank': 685},
#  {'article': 'فيودور_دوستويفسكي', 'views': 730, 'rank': 685},
#  {'article': 'الطبيب_المعجزة', 'views': 729, 'rank': 687},
#  {'article': 'قائمة_المسلسلات_التركية_المدبلجة', 'views': 729, 'rank': 687},
#  {'article': 'طاقة_متجددة', 'views': 729, 'rank': 687},
#  {'article': 'يوسف', 'views': 729, 'rank': 687},
#  {'article': 'دمشق', 'views': 728, 'rank': 691},
#  {'article': 'هيا_عبد_السلام', 'views': 726, 'rank': 692},
#  {'article': 'مضاد_فيروسات_(دواء)', 'views': 726, 'rank': 692},
#  {'article': 'دانيال', 'views': 725, 'rank': 694},
#  {'article': 'جينوم_بشري', 'views': 723, 'rank': 695},
#  {'article': 'تفاعلات_أكسدة-اختزال', 'views': 723, 'rank': 695},
#  {'article': 'برج_السرطان', 'views': 723, 'rank': 695},
#  {'article': 'ماركسية', 'views': 722, 'rank': 698},
#  {'article': 'حرب_1967', 'views': 722, 'rank': 698},
#  {'article': 'سعد_بن_أبي_وقاص', 'views': 721, 'rank': 700},
#  {'article': 'آرلينغ_هالاند', 'views': 720, 'rank': 701},
#  {'article': 'العهد_العباسي_الثاني', 'views': 720, 'rank': 701},
#  {'article': 'ممارسات_جنسية_مثلية', 'views': 719, 'rank': 703},
#  {'article': 'سورة_الفاتحة', 'views': 719, 'rank': 703},
#  {'article': 'الهجرة_إلى_الحبشة', 'views': 718, 'rank': 705},
#  {'article': 'انتصار_عامر', 'views': 718, 'rank': 705},
#  {'article': 'هولندا', 'views': 718, 'rank': 705},
#  {'article': 'مراهقة', 'views': 717, 'rank': 708},
#  {'article': 'عود_(آلة_موسيقية)', 'views': 717, 'rank': 708},
#  {'article': 'أحكام_النون_الساكنة_والتنوين', 'views': 717, 'rank': 708},
#  {'article': 'ميرفت_أمين', 'views': 717, 'rank': 708},
#  {'article': 'أنجلينا_جولي', 'views': 716, 'rank': 712},
#  {'article': 'سلطان_بن_عبد_العزيز_آل_سعود', 'views': 716, 'rank': 712},
#  {'article': 'رؤية_السعودية_2030', 'views': 714, 'rank': 714},
#  {'article': 'ماكدونالدز', 'views': 714, 'rank': 714},
#  {'article': 'إلحاد', 'views': 712, 'rank': 716},
#  {'article': 'غزوات_الرسول_محمد', 'views': 712, 'rank': 716},
#  {'article': 'قبيلة_حرب', 'views': 711, 'rank': 718},
#  {'article': 'جابر_الأحمد_الصباح', 'views': 710, 'rank': 719},
#  {'article': 'سمير_غانم', 'views': 710, 'rank': 719},
#  {'article': 'أسماء_النبي_محمد', 'views': 708, 'rank': 721},
#  {'article': 'تامر_حسني', 'views': 707, 'rank': 722},
#  {'article': 'عبد_الله_الثاني_بن_الحسين', 'views': 707, 'rank': 722},
#  {'article': 'تصلب_جانبي_ضموري', 'views': 707, 'rank': 722},
#  {'article': 'نسبة_مئوية', 'views': 707, 'rank': 722},
#  {'article': 'علويون_(طائفة)', 'views': 706, 'rank': 726},
#  {'article': 'عهد_الدم_(مسلسل)', 'views': 706, 'rank': 726},
#  {'article': 'جهاز_هضمي', 'views': 705, 'rank': 728},
#  {'article': 'الأمم_المتحدة', 'views': 705, 'rank': 728},
#  {'article': 'أبو_حامد_الغزالي', 'views': 705, 'rank': 728},
#  {'article': 'سعد_الدين_الشاذلي', 'views': 705, 'rank': 728},
#  {'article': 'قائمة_الممثلين_المصريين', 'views': 704, 'rank': 732},
#  {'article': 'عصر_صدر_الإسلام', 'views': 704, 'rank': 732},
#  {'article': 'أنس_بن_مالك', 'views': 703, 'rank': 734},
#  {'article': 'قريش', 'views': 701, 'rank': 735},
#  {'article': 'قوانين_نيوتن_للحركة', 'views': 701, 'rank': 735},
#  {'article': 'ديمقراطية', 'views': 700, 'rank': 737},
#  {'article': 'شبه_الجزيرة_العربية', 'views': 699, 'rank': 738},
#  {'article': 'القمر', 'views': 699, 'rank': 738},
#  {'article': 'نفط', 'views': 699, 'rank': 738},
#  {'article': 'ذرة', 'views': 698, 'rank': 741},
#  {'article': 'جدة', 'views': 698, 'rank': 741},
#  {'article': 'المعتزلة', 'views': 697, 'rank': 743},
#  {'article': 'بنت', 'views': 697, 'rank': 743},
#  {'article': 'البحر_الأبيض_المتوسط', 'views': 697, 'rank': 743},
#  {'article': 'واتساب', 'views': 696, 'rank': 746},
#  {'article': 'مواقع_إباحية', 'views': 696, 'rank': 746},
#  {'article': 'أحمد_حلمي', 'views': 695, 'rank': 748},
#  {'article': 'أبل', 'views': 695, 'rank': 748},
#  {'article': 'ويكيبيديا:تصفح', 'views': 694, 'rank': 750},
#  {'article': 'خفاشيات', 'views': 693, 'rank': 751},
#  {'article': 'تحية_كاريوكا', 'views': 693, 'rank': 751},
#  {'article': 'إدلب', 'views': 693, 'rank': 751},
#  {'article': 'قحطان_(قبيلة)', 'views': 693, 'rank': 751},
#  {'article': 'محمد_بن_عبد_الوهاب', 'views': 692, 'rank': 755},
#  {'article': 'شهور_سريانية', 'views': 691, 'rank': 756},
#  {'article': 'المكسيك', 'views': 690, 'rank': 757},
#  {'article': 'مشهد_(إيران)', 'views': 689, 'rank': 758},
#  {'article': 'بطولات_نادي_الزمالك_لكرة_القدم', 'views': 689, 'rank': 758},
#  {'article': 'وليم_شكسبير', 'views': 689, 'rank': 758},
#  {'article': 'كليب_بن_ربيعة', 'views': 689, 'rank': 758},
#  {'article': 'جمل', 'views': 688, 'rank': 762},
#  {'article': 'محمد_زيدان', 'views': 688, 'rank': 762},
#  {'article': 'شيعة_اثنا_عشرية', 'views': 688, 'rank': 762},
#  {'article': 'ليوناردو_دا_فينشي', 'views': 687, 'rank': 765},
#  {'article': 'أبو_جهل', 'views': 687, 'rank': 765},
#  {'article': 'فوزية_بنت_فؤاد_الأول', 'views': 686, 'rank': 767},
#  {'article': 'جائحة_إنفلونزا_الخنازير_2009', 'views': 685, 'rank': 768},
#  {'article': 'الشمس', 'views': 685, 'rank': 768},
#  {'article': 'شخصيات_مخفية_(فيلم)', 'views': 685, 'rank': 768},
#  {'article': 'قائمة_مسلسلات_الأنمي_والرسوم_المتحركة_المدبلجة_للعربية',
#   'views': 684,
#   'rank': 771},
#  {'article': 'سقوط_الأندلس', 'views': 684, 'rank': 771},
#  {'article': 'الدوري_الإنجليزي_الممتاز_2003–04', 'views': 684, 'rank': 771},
#  {'article': 'نادي_الشباب_(السعودية)', 'views': 684, 'rank': 771},
#  {'article': 'البحر_الميت', 'views': 683, 'rank': 775},
#  {'article': 'سليم_الأول', 'views': 683, 'rank': 775},
#  {'article': 'ياسر_عرفات', 'views': 682, 'rank': 777},
#  {'article': 'جهاز_عصبي', 'views': 682, 'rank': 777},
#  {'article': 'ياسمين_صبري', 'views': 681, 'rank': 779},
#  {'article': 'عمرو_بن_العاص', 'views': 680, 'rank': 780},
#  {'article': 'إسلام', 'views': 680, 'rank': 780},
#  {'article': 'خليفة_بن_زايد_آل_نهيان', 'views': 679, 'rank': 782},
#  {'article': 'عدد_أولي', 'views': 679, 'rank': 782},
#  {'article': 'أبو_العلاء_المعري', 'views': 679, 'rank': 782},
#  {'article': 'سليمان', 'views': 678, 'rank': 785},
#  {'article': 'فتح_القسطنطينية', 'views': 678, 'rank': 785},
#  {'article': 'شجر_الدر', 'views': 678, 'rank': 785},
#  {'article': 'تيم_حسن', 'views': 677, 'rank': 788},
#  {'article': 'يحيى_الفخراني', 'views': 677, 'rank': 788},
#  {'article': 'رستميون', 'views': 676, 'rank': 790},
#  {'article': 'أبجدية_عربية', 'views': 675, 'rank': 791},
#  {'article': 'ذو_القرنين', 'views': 675, 'rank': 791},
#  {'article': 'إباحية', 'views': 674, 'rank': 793},
#  {'article': 'تيتانيك_(فيلم_1997)', 'views': 674, 'rank': 793},
#  {'article': 'إباضية', 'views': 673, 'rank': 795},
#  {'article': 'الحجر_الأسود', 'views': 673, 'rank': 795},
#  {'article': 'روز', 'views': 671, 'rank': 797},
#  {'article': 'اسم_فاعل', 'views': 671, 'rank': 797},
#  {'article': 'الحرب_الباردة', 'views': 670, 'rank': 799},
#  {'article': 'علم_الفلك', 'views': 670, 'rank': 799},
#  {'article': 'كارثة_تشيرنوبل', 'views': 670, 'rank': 799},
#  {'article': 'بيكي_بلايندرز_(مسلسل_تلفزيوني)', 'views': 670, 'rank': 799},
#  {'article': 'لغة_فرنسية', 'views': 669, 'rank': 803},
#  {'article': 'الحرب_في_أفغانستان_(2001–الآن)', 'views': 669, 'rank': 803},
#  {'article': 'الفاتيكان', 'views': 668, 'rank': 805},
#  {'article': 'حرب_الخليج_الأولى', 'views': 668, 'rank': 805},
#  {'article': 'قابيل_وهابيل', 'views': 667, 'rank': 807},
#  {'article': 'سادية_مازوخية', 'views': 666, 'rank': 808},
#  {'article': 'كأس_العالم', 'views': 666, 'rank': 808},
#  {'article': 'الملائكة_في_الإسلام', 'views': 666, 'rank': 808},
#  {'article': 'كلية', 'views': 666, 'rank': 808},
#  {'article': 'آسيا', 'views': 665, 'rank': 812},
#  {'article': 'فيزياء', 'views': 665, 'rank': 812},
#  {'article': 'مشعل_بن_سعود_بن_عبد_العزيز_آل_سعود', 'views': 664, 'rank': 814},
#  {'article': 'فايكنج', 'views': 664, 'rank': 814},
#  {'article': 'السلفادور', 'views': 664, 'rank': 814},
#  {'article': 'محمد_نجيب', 'views': 664, 'rank': 814},
#  {'article': 'جراند_ثفت_أوتو:_سان_أندرياس', 'views': 663, 'rank': 818},
#  {'article': 'علم_الاجتماع', 'views': 663, 'rank': 818},
#  {'article': 'فلسفة', 'views': 663, 'rank': 818},
#  {'article': 'قناة_السويس', 'views': 663, 'rank': 818},
#  {'article': 'يزيد_بن_معاوية', 'views': 663, 'rank': 818},
#  {'article': 'وباء', 'views': 662, 'rank': 823},
#  {'article': 'أمهات_المؤمنين', 'views': 662, 'rank': 823},
#  {'article': 'أنبياء_مذكورون_في_القرآن_الكريم', 'views': 661, 'rank': 825},
#  {'article': 'حجر_كريم', 'views': 660, 'rank': 826},
#  {'article': 'محمد_أبو_تريكة', 'views': 660, 'rank': 826},
#  {'article': 'غلاف_الأرض_الجوي', 'views': 659, 'rank': 828},
#  {'article': 'انخفاض_ضغط_الدم', 'views': 659, 'rank': 828},
#  {'article': 'معمر_القذافي', 'views': 658, 'rank': 830},
#  {'article': 'هيموغلوبين', 'views': 658, 'rank': 830},
#  {'article': 'مريم_بنت_عمران', 'views': 658, 'rank': 830},
#  {'article': 'معلقة_عمرو_بن_كلثوم', 'views': 658, 'rank': 830},
#  {'article': 'الدولة_السعودية_الأولى', 'views': 657, 'rank': 834},
#  {'article': 'شمر_(قبيلة)', 'views': 657, 'rank': 834},
#  {'article': 'إنا_لله_وإنا_إليه_راجعون', 'views': 657, 'rank': 834},
#  {'article': 'فاتن_حمامة', 'views': 657, 'rank': 834},
#  {'article': 'مي_عز_الدين', 'views': 657, 'rank': 834},
#  {'article': 'لبان', 'views': 657, 'rank': 834},
#  {'article': 'حسان_بن_ثابت', 'views': 656, 'rank': 840},
#  {'article': 'عجائب_الدنيا_السبع_الجديدة', 'views': 656, 'rank': 840},
#  {'article': 'زين_الدين_زيدان', 'views': 655, 'rank': 842},
#  {'article': 'دولار_أمريكي', 'views': 655, 'rank': 842},
#  {'article': 'الإسلام_حسب_البلد', 'views': 654, 'rank': 844},
#  {'article': 'برج_إيفل', 'views': 653, 'rank': 845},
#  {'article': 'نمرود', 'views': 652, 'rank': 846},
#  {'article': 'بحر_الطويل', 'views': 652, 'rank': 846},
#  {'article': 'محمد_السادس_بن_الحسن', 'views': 652, 'rank': 846},
#  {'article': 'ذهب', 'views': 652, 'rank': 846},
#  {'article': 'الكراغلة', 'views': 652, 'rank': 846},
#  {'article': 'كليلة_ودمنة', 'views': 652, 'rank': 846},
#  {'article': 'ليوناردو_دي_كابريو', 'views': 650, 'rank': 852},
#  {'article': 'القوات_المسلحة_التركية', 'views': 650, 'rank': 852},
#  {'article': 'عبد_العزيز_بن_باز', 'views': 649, 'rank': 854},
#  {'article': 'حمد_بن_خليفة_آل_ثاني', 'views': 649, 'rank': 854},
#  {'article': 'العدوان_الثلاثي', 'views': 648, 'rank': 856},
#  {'article': 'البرازيل', 'views': 647, 'rank': 857},
#  {'article': 'فيتامين_سي', 'views': 647, 'rank': 857},
#  {'article': 'الشرق_الأوسط', 'views': 646, 'rank': 859},
#  {'article': 'حيوان', 'views': 646, 'rank': 859},
#  {'article': 'عبد_الباسط_عبد_الصمد', 'views': 645, 'rank': 861},
#  {'article': 'القوات_المسلحة_المصرية', 'views': 645, 'rank': 861},
#  {'article': 'عبد_الحسين_عبد_الرضا', 'views': 644, 'rank': 863},
#  {'article': 'محافظة_إدلب', 'views': 644, 'rank': 863},
#  {'article': 'جائزة_نوبل', 'views': 643, 'rank': 865},
#  {'article': 'الوليد_بن_طلال_بن_عبد_العزيز_آل_سعود',
#   'views': 643,
#   'rank': 865},
#  {'article': 'بنغلاديش', 'views': 642, 'rank': 867},
#  {'article': 'كرد', 'views': 642, 'rank': 867},
#  {'article': 'شيماء_علي', 'views': 642, 'rank': 867},
#  {'article': 'ألف_ليلة_وليلة', 'views': 641, 'rank': 870},
#  {'article': 'مصادر_التشريع_الإسلامي', 'views': 641, 'rank': 870},
#  {'article': 'مدائن_صالح', 'views': 641, 'rank': 870},
#  {'article': 'مني', 'views': 641, 'rank': 870},
#  {'article': 'صراع_العروش', 'views': 640, 'rank': 874},
#  {'article': 'علي_الطنطاوي', 'views': 640, 'rank': 874},
#  {'article': 'الهجرة_النبوية', 'views': 640, 'rank': 874},
#  {'article': 'خلية', 'views': 640, 'rank': 874},
#  {'article': 'الفتح_الإسلامي_للأندلس', 'views': 640, 'rank': 874},
#  {'article': 'مهنة', 'views': 640, 'rank': 874},
#  {'article': 'رياض_السنباطي', 'views': 638, 'rank': 880},
#  {'article': 'الخلافة_الراشدة', 'views': 638, 'rank': 880},
#  {'article': 'قائمة_نهائيات_دوري_أبطال_أفريقيا', 'views': 637, 'rank': 882},
#  {'article': 'ترجمة', 'views': 637, 'rank': 882},
#  {'article': 'أحمد_شفيق', 'views': 636, 'rank': 884},
#  {'article': 'نادي_الزمالك_لكرة_القدم_في_أفريقيا', 'views': 636, 'rank': 884},
#  {'article': 'مجدي_راسخ', 'views': 635, 'rank': 886},
#  {'article': 'يهود', 'views': 635, 'rank': 886},
#  {'article': 'صد', 'views': 635, 'rank': 886},
#  {'article': 'وضع_كلابي', 'views': 635, 'rank': 886},
#  {'article': 'سورة_الكهف', 'views': 634, 'rank': 890},
#  {'article': 'معجزات_الرسول_محمد', 'views': 634, 'rank': 890},
#  {'article': 'أرسطو', 'views': 633, 'rank': 892},
#  {'article': 'قواعد_العشق_الأربعون_(كتاب)', 'views': 632, 'rank': 893},
#  {'article': 'إدريس', 'views': 632, 'rank': 893},
#  {'article': 'أحمد_عز_(ممثل)', 'views': 632, 'rank': 893},
#  {'article': 'تنمية_مستدامة', 'views': 632, 'rank': 893},
#  {'article': 'سقراط', 'views': 631, 'rank': 897},
#  {'article': 'ولايات_الجزائر', 'views': 631, 'rank': 897},
#  {'article': 'قيس_بن_الملوح', 'views': 631, 'rank': 897},
#  {'article': 'أغالبة', 'views': 630, 'rank': 900},
#  {'article': 'مترو_أنفاق_القاهرة', 'views': 630, 'rank': 900},
#  {'article': 'حدائق_بابل_المعلقة', 'views': 630, 'rank': 900},
#  {'article': 'المريخ', 'views': 630, 'rank': 900},
#  {'article': 'جمال_الدين_الأفغاني', 'views': 629, 'rank': 904},
#  {'article': 'قائمة_الدول_حسب_إنتاج_النفط', 'views': 627, 'rank': 905},
#  {'article': 'جاستن_بيبر', 'views': 627, 'rank': 905},
#  {'article': 'خولة_سليماني', 'views': 626, 'rank': 907},
#  {'article': 'المسجد_الحرام', 'views': 626, 'rank': 907},
#  {'article': 'إحصائيات_الدوري_السعودي', 'views': 626, 'rank': 907},
#  {'article': 'محمد_ناصر_الدين_الألباني', 'views': 626, 'rank': 907},
#  {'article': 'قط', 'views': 625, 'rank': 911},
#  {'article': 'يعقوب', 'views': 625, 'rank': 911},
#  {'article': 'حركة_انتصار_الحريات_الديمقراطية', 'views': 624, 'rank': 913},
#  {'article': 'جهاد', 'views': 623, 'rank': 914},
#  {'article': 'السويد', 'views': 622, 'rank': 915},
#  {'article': 'أبو_الريحان_البيروني', 'views': 622, 'rank': 915},
#  {'article': 'فريد_شوقي', 'views': 621, 'rank': 917},
#  {'article': 'لولوة_الفيصل_بن_عبد_العزيز_آل_سعود', 'views': 620, 'rank': 918},
#  {'article': 'أفلاطون', 'views': 620, 'rank': 918},
#  {'article': 'قائمة_مدن_مصر', 'views': 620, 'rank': 918},
#  {'article': 'قائمة_الفواكه', 'views': 620, 'rank': 918},
#  {'article': 'هاتف_محمول', 'views': 620, 'rank': 918},
#  {'article': 'موسيقى', 'views': 620, 'rank': 918},
#  {'article': 'عقبة_بن_نافع', 'views': 620, 'rank': 918},
#  {'article': 'بر_الوالدين', 'views': 620, 'rank': 918},
#  {'article': 'أرقام_عربية', 'views': 619, 'rank': 926},
#  {'article': 'شيكابالا', 'views': 619, 'rank': 926},
#  {'article': 'كأس_السوبر_الأفريقي', 'views': 619, 'rank': 926},
#  {'article': 'نقص_فيتامين_بي_12', 'views': 619, 'rank': 926},
#  {'article': 'الحج_في_الإسلام', 'views': 619, 'rank': 926},
#  {'article': 'المحقق_كونان', 'views': 618, 'rank': 931},
#  {'article': 'نسرين_طافش', 'views': 617, 'rank': 932},
#  {'article': 'حافظ_الأسد', 'views': 616, 'rank': 933},
#  {'article': 'جهيمان_العتيبي', 'views': 615, 'rank': 934},
#  {'article': 'النجم_الرياضي_الساحلي', 'views': 615, 'rank': 934},
#  {'article': 'الإسكندرية', 'views': 615, 'rank': 934},
#  {'article': 'ليبرالية', 'views': 615, 'rank': 934},
#  {'article': 'قصة_أصحاب_الأخدود', 'views': 614, 'rank': 938},
#  {'article': 'مسيحية', 'views': 613, 'rank': 939},
#  {'article': 'القيروان', 'views': 613, 'rank': 939},
#  {'article': 'نور_نعيم', 'views': 613, 'rank': 939},
#  {'article': 'جلال_الدين_الرومي', 'views': 613, 'rank': 939},
#  {'article': 'الصلاة_على_النبي', 'views': 612, 'rank': 943},
#  {'article': 'مقدمة_ابن_خلدون', 'views': 612, 'rank': 943},
#  {'article': 'مرتضى_منصور', 'views': 612, 'rank': 943},
#  {'article': 'طاقة_شمسية', 'views': 612, 'rank': 943},
#  {'article': 'احتلام', 'views': 612, 'rank': 943},
#  {'article': 'ابن_بطوطة', 'views': 612, 'rank': 943},
#  {'article': 'قائمة_المسلسلات_التلفزيونية_المصرية', 'views': 612, 'rank': 943},
#  {'article': 'حساب_عيد_الفصح_المسيحي', 'views': 609, 'rank': 950},
#  {'article': 'موقعة_الجمل', 'views': 609, 'rank': 950},
#  {'article': 'بيان_فيفري_1943', 'views': 609, 'rank': 950},
#  {'article': 'شركة_المراعي', 'views': 609, 'rank': 950},
#  {'article': 'أنجيلا_وايت', 'views': 608, 'rank': 954},
#  {'article': 'زواج_المسيار', 'views': 607, 'rank': 955},
#  {'article': 'عبد_الله_بن_عباس', 'views': 607, 'rank': 955},
#  {'article': 'فيل', 'views': 607, 'rank': 955},
#  {'article': 'اشتراكية', 'views': 607, 'rank': 955},
#  {'article': 'يوم_المعلم', 'views': 607, 'rank': 955},
#  {'article': 'داليا_مصطفى', 'views': 606, 'rank': 960},
#  {'article': 'وسائل_تواصل_اجتماعي', 'views': 605, 'rank': 961},
#  {'article': 'رجب', 'views': 605, 'rank': 961},
#  {'article': 'عنف', 'views': 605, 'rank': 961},
#  {'article': 'مضاد_حيوي', 'views': 605, 'rank': 961},
#  {'article': 'بدر_بن_عبد_المحسن_بن_عبد_العزيز_آل_سعود',
#   'views': 605,
#   'rank': 961},
#  {'article': 'كلوروكين', 'views': 604, 'rank': 966},
#  {'article': 'إبليس', 'views': 604, 'rank': 966},
#  {'article': 'صناعة_تقليدية_مغربية', 'views': 604, 'rank': 966},
#  {'article': 'إليسا', 'views': 603, 'rank': 969},
#  {'article': 'لواء_إسكندرون', 'views': 603, 'rank': 969},
#  {'article': 'أشعرية', 'views': 602, 'rank': 971},
#  {'article': 'آنا_مالي', 'views': 602, 'rank': 971},
#  {'article': 'مطير_(قبيلة)', 'views': 601, 'rank': 973},
#  {'article': 'يهودية', 'views': 601, 'rank': 973},
#  {'article': 'حياة_الفهد', 'views': 601, 'rank': 973},
#  {'article': 'عبد_الملك_بن_مروان', 'views': 600, 'rank': 976},
#  {'article': 'فلاديمير_بوتين', 'views': 600, 'rank': 976},
#  {'article': 'مارلين_مونرو', 'views': 599, 'rank': 978},
#  {'article': 'آيتشا_آيشين_توران', 'views': 599, 'rank': 978},
#  {'article': 'غزوة_مؤتة', 'views': 598, 'rank': 980},
#  {'article': 'ويلفريد_بوني', 'views': 598, 'rank': 980},
#  {'article': 'بحر_البسيط', 'views': 598, 'rank': 980},
#  {'article': 'زهير_رمضان', 'views': 597, 'rank': 983},
#  {'article': 'إلهام_الفضالة', 'views': 597, 'rank': 983},
#  {'article': 'طارق_بن_زياد', 'views': 597, 'rank': 983},
#  {'article': 'معركة_وادي_المخازن', 'views': 596, 'rank': 986},
#  {'article': 'بلاد_الشام', 'views': 595, 'rank': 987},
#  {'article': 'النرويج', 'views': 595, 'rank': 987},
#  {'article': 'طلال_مداح', 'views': 595, 'rank': 987},
#  {'article': 'عباس_النوري', 'views': 594, 'rank': 990},
#  {'article': 'سنة_بسيطة', 'views': 594, 'rank': 990},
#  {'article': 'هجمات_الشمال_القسنطيني', 'views': 592, 'rank': 992},
#  {'article': 'تي_بي_مازيمبي', 'views': 591, 'rank': 993},
#  {'article': 'حكم_الاستمناء_في_الإسلام', 'views': 591, 'rank': 993},
#  {'article': 'فريد_فتى', 'views': 591, 'rank': 993},
#  {'article': 'فيروس_كورونا_المرتبط_بالمتلازمة_التنفسية_الحادة_الوخيمة',
#   'views': 591,
#   'rank': 993},
#  {'article': 'النادي_الفيصلي_(الأردن)', 'views': 590, 'rank': 997},
#  {'article': 'هدى_شعراوي', 'views': 589, 'rank': 998},
#  {'article': 'رمسيس_الثاني', 'views': 589, 'rank': 998}]

# %%
import pandas as pd
import numpy as np

# %%
date1 = '2022-08-28'
date2 = '2023-08-28'
dates = pd.date_range(date1, date2).tolist()

# %%
dates[0].strftime('%Y')
# Out:
# '2022'

# %%
dates
# Out:
# [Timestamp('2022-08-28 00:00:00', freq='D'),
#  Timestamp('2022-08-29 00:00:00', freq='D'),
#  Timestamp('2022-08-30 00:00:00', freq='D'),
#  Timestamp('2022-08-31 00:00:00', freq='D'),
#  Timestamp('2022-09-01 00:00:00', freq='D'),
#  Timestamp('2022-09-02 00:00:00', freq='D'),
#  Timestamp('2022-09-03 00:00:00', freq='D'),
#  Timestamp('2022-09-04 00:00:00', freq='D'),
#  Timestamp('2022-09-05 00:00:00', freq='D'),
#  Timestamp('2022-09-06 00:00:00', freq='D'),
#  Timestamp('2022-09-07 00:00:00', freq='D'),
#  Timestamp('2022-09-08 00:00:00', freq='D'),
#  Timestamp('2022-09-09 00:00:00', freq='D'),
#  Timestamp('2022-09-10 00:00:00', freq='D'),
#  Timestamp('2022-09-11 00:00:00', freq='D'),
#  Timestamp('2022-09-12 00:00:00', freq='D'),
#  Timestamp('2022-09-13 00:00:00', freq='D'),
#  Timestamp('2022-09-14 00:00:00', freq='D'),
#  Timestamp('2022-09-15 00:00:00', freq='D'),
#  Timestamp('2022-09-16 00:00:00', freq='D'),
#  Timestamp('2022-09-17 00:00:00', freq='D'),
#  Timestamp('2022-09-18 00:00:00', freq='D'),
#  Timestamp('2023-08-14 00:00:00', freq='D'),
#  Timestamp('2023-08-15 00:00:00', freq='D'),
#  Timestamp('2023-08-16 00:00:00', freq='D'),
#  Timestamp('2023-08-17 00:00:00', freq='D'),
#  Timestamp('2023-08-18 00:00:00', freq='D'),
#  Timestamp('2023-08-19 00:00:00', freq='D'),
#  Timestamp('2023-08-20 00:00:00', freq='D'),
#  Timestamp('2023-08-21 00:00:00', freq='D'),
#  Timestamp('2023-08-22 00:00:00', freq='D'),
#  Timestamp('2023-08-23 00:00:00', freq='D'),
#  Timestamp('2023-08-24 00:00:00', freq='D'),
#  Timestamp('2023-08-25 00:00:00', freq='D'),
#  Timestamp('2023-08-26 00:00:00', freq='D'),
#  Timestamp('2023-08-27 00:00:00', freq='D'),
#  Timestamp('2023-08-28 00:00:00', freq='D')]

# %%
#array of 25 most popular articles
top_array = []

for date in dates:
    year=date.strftime('%Y')
    month = date.strftime('%m')
    day = date.strftime('%d')
    print(date)
#     wiki_info = get_wiki_info('en', 'wikipedia')
    raw_traffic = get_traffic(year, month, day)
    articles = [a for a in raw_traffic if is_article(a['article'], wiki_info)]
    top_array.append(articles[:25])
# Out:
# 2022-08-28 00:00:00
# 2022-08-29 00:00:00
# 2022-08-30 00:00:00
# 2022-08-31 00:00:00
# 2022-09-01 00:00:00
# 2022-09-02 00:00:00
# 2022-09-03 00:00:00
# 2022-09-04 00:00:00
# 2022-09-05 00:00:00
# 2022-09-06 00:00:00
# 2022-09-07 00:00:00
# 2022-09-08 00:00:00
# 2022-09-09 00:00:00
# 2022-09-10 00:00:00
# 2022-09-11 00:00:00
# 2022-09-12 00:00:00
# 2022-09-13 00:00:00
# 2022-09-14 00:00:00
# 2022-09-15 00:00:00
# 2022-09-16 00:00:00
# 2022-09-17 00:00:00
# 2022-09-18 00:00:00
# 2022-09-19 00:00:00
# 2022-09-20 00:00:00
# 2022-09-21 00:00:00
# 2022-09-22 00:00:00
# 2022-09-23 00:00:00
# 2022-09-24 00:00:00
# 2022-09-25 00:00:00
# 2022-09-26 00:00:00
# 2022-09-27 00:00:00
# 2022-09-28 00:00:00
# 2022-09-29 00:00:00
# 2022-09-30 00:00:00
# 2022-10-01 00:00:00
# 2022-10-02 00:00:00
# 2022-10-03 00:00:00
# 2022-10-04 00:00:00
# 2022-10-05 00:00:00
# 2022-10-06 00:00:00
# 2022-10-07 00:00:00
# 2022-10-08 00:00:00
# 2022-10-09 00:00:00
# 2022-10-10 00:00:00
# 2022-10-11 00:00:00
# 2022-10-12 00:00:00
# 2022-10-13 00:00:00
# 2022-10-14 00:00:00
# 2022-10-15 00:00:00
# 2022-10-16 00:00:00
# 2022-10-17 00:00:00
# 2022-10-18 00:00:00
# 2022-10-19 00:00:00
# 2022-10-20 00:00:00
# 2022-10-21 00:00:00
# 2022-10-22 00:00:00
# 2022-10-23 00:00:00
# 2022-10-24 00:00:00
# 2022-10-25 00:00:00
# 2022-10-26 00:00:00
# 2022-10-27 00:00:00
# 2022-10-28 00:00:00
# 2022-10-29 00:00:00
views_array = []
articles_array = []
ranks_array = []

for i in range(len(top_array)):
    date = dates[i]
    array = top_array[i]
    for j in range(25):
        row = array[j]
        dates_array.append(date)
        articles_array.append(row['article'].replace('_', ' '))
#         print(articles_array)
        views_array.append(row['views'])
        ranks_array.append(row['rank'])

# %%
len(dates_array)
# articles_array
# Out:
# 9150

# %%
dict = {'date': dates_array, 'article': articles_array, 'views': views_array, 'rank': ranks_array}
df = pd.DataFrame(data=dict)
df
# Out:
#            date          article  views  rank
# 0    2022-08-28  الصفحة الرئيسية  77475     1
# 1    2022-08-28      جورج الراسي  49742     2
# 2    2022-08-28          خاص:بحث  44480     3
# 3    2022-08-28           ميدوسا  24442     4
# 4    2022-08-28     نادين الراسي  20156     5
# ...         ...              ...    ...   ...
# 9145 2023-08-28     نادي ليفربول   5546    21
# 9146 2023-08-28   صلاة الاستخارة   5512    22
# 9147 2023-08-28        ميا خليفة   5406    23
# 9148 2023-08-28    جاكسون موليكا   5399    24
# 9149 2023-08-28             محمد   5296    25
#
# [9150 rows x 4 columns]

# %%
df[df.article == "United States Senate"]
# Out:
# Empty DataFrame
# Columns: [date, article, views, rank]
# Index: []

# %%
df.sort_values(by="views", ascending=False)
# Out:
#            date                   article   views  rank
# 7200 2023-06-12           الصفحة الرئيسية  676881     1
# 275  2022-09-08          إليزابيث الثانية  488324     1
# 2100 2022-11-20           كأس العالم 2022  380824     1
# 300  2022-09-09          إليزابيث الثانية  351975     1
# 1450 2022-10-25                كسوف الشمس  318111     1
# ...         ...                       ...     ...   ...
# 7947 2023-07-11           علي بن أبي طالب    3651    23
# 7823 2023-07-06                     يوليو    3626    24
# 7948 2023-07-11  قائمة محطات مترو القاهرة    3607    24
# 7949 2023-07-11                       مصر    3589    25
# 7824 2023-07-06              كيليان مبابي    3556    25
#
# [9150 rows x 4 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.groupby('article').count()
# Out:
#                     date  views  rank
# article
# 2023                   1      1     1
# 2029                   3      3     3
# 21 مارس                1      1     1
# آر إم إس تيتانيك      12     12    12
# آرثر ميلو              1      1     1
# ...                  ...    ...   ...
# يوم المعلم             2      2     2
# يوم المعلم العالمي     4      4     4
# يوم النصر (تركيا)      1      1     1
# يوم عرفة              12     12    12
# يوهانس برامس           3      3     3
#
# [1343 rows x 3 columns]

# %%
df.groupby('article').agg({'date':'first',
                         'views':'max',
                         'rank':'count'}).sort_values(by=['views'], ascending=False)
# Out:
#                                               date   views  rank
# article
# الصفحة الرئيسية                         2022-08-28  676881   366
# إليزابيث الثانية                        2022-09-08  488324    22
# كأس العالم 2022                         2022-09-06  380824   109
# كسوف الشمس                              2022-10-23  318111     5
# كأس العالم                              2022-11-03  299466    58
# ...                                            ...     ...   ...
# أبشر                                    2022-08-28    3999     2
# كوسوفو                                  2022-12-28    3901     1
# عبد الصمد الزلزولي                      2023-07-09    3877     1
# الجمهورية العربية الصحراوية الديمقراطية 2022-08-28    3730     1
# سوسن علي                                2022-12-29    3694     1
#
# [1343 rows x 3 columns]

# %%
df.to_csv('wiki_pageviews_jan-jan.csv')
